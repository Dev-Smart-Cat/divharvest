# %% [markdown]
# https://medium.com/@geovasconcelos/impulsione-seus-investimentos-aprenda-a-utilizar-web-scraping-em-python-para-comparar-indicadores-110b2ca7c4d8

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
stock_code = "BBSE3"

# %%
# url to access the dividend history adding the stock code
div_url = f"https://www.fundamentus.com.br/proventos.php?papel={stock_code}&tipo=2"

# %%
# headers is used to identify as a real browser when sending a HTTP request to the server,
# the header identify the OS, browsr and Mozilla/5.0 as all browser keep this for compatibility
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
}

# %%
# Make the HTTP request to the server using the url and the human identifier (User-Agent) 
stock_response = requests.get(div_url, headers=headers)

# %%
# Parse (analyse) the HTML response/text into a structured object, 
# making it possible to search and extract data using HTML tags (e.g. <table>, <td> )
stock_soup = BeautifulSoup(stock_response.text, "html.parser")

# %% [markdown]
# ### HTML Acronyms:
#
# `<table>` table \
# `<thead>` table head \
# `<tbody>` table body \
# `<tfoot>` table foot \
# `<tr>` table row \
# `<td>` table data \
# `<th>` table header

# %%
# Search for content using the tag <table>, 
# since the dividends history is in a table
stock_table = stock_soup.find("table")

# %%
# Search for the table's content using the tag <tbody>,
# then collect all rows using <tr> tag to iterate line by line 
div_payment_info_rows = stock_table.find("tbody").find_all("tr")

# %%
# List to append the dividends payment dates
payment_dates_list = []

# 
for row in div_payment_info_rows:
    cols = row.find_all("td")
    print(cols)
# Out:
# [<td>12/02/2026</td>, <td>2,5500</td>, <td>DIVIDENDO</td>, <td>02/03/2026							  </td>, <td>1</td>]
# [<td>14/08/2025</td>, <td>1,9421</td>, <td>DIVIDENDO</td>, <td>26/08/2025							  </td>, <td>1</td>]
# [<td>20/02/2025</td>, <td>2,2723</td>, <td>DIVIDENDO</td>, <td>06/03/2025							  </td>, <td>1</td>]
# [<td>16/08/2024</td>, <td>1,3909</td>, <td>DIVIDENDO</td>, <td>30/08/2024							  </td>, <td>1</td>]
# [<td>08/02/2024</td>, <td>1,2419</td>, <td>DIVIDENDO</td>, <td>22/02/2024							  </td>, <td>1</td>]
# [<td>16/08/2023</td>, <td>1,6076</td>, <td>DIVIDENDO</td>, <td>28/08/2023							  </td>, <td>1</td>]
# [<td>14/02/2023</td>, <td>1,8399</td>, <td>DIVIDENDO</td>, <td>01/03/2023							  </td>, <td>1</td>]
# [<td>17/08/2022</td>, <td>1,0360</td>, <td>DIVIDENDO</td>, <td>29/08/2022							  </td>, <td>1</td>]
# [<td>10/02/2022</td>, <td>0,9172</td>, <td>DIVIDENDO</td>, <td>23/02/2022							  </td>, <td>1</td>]
# [<td>11/08/2021</td>, <td>0,5209</td>, <td>DIVIDENDO</td>, <td>23/08/2021							  </td>, <td>1</td>]
# [<td>11/02/2021</td>, <td>0,4748</td>, <td>DIVIDENDO</td>, <td>25/02/2021							  </td>, <td>1</td>]
# [<td>12/08/2020</td>, <td>0,8753</td>, <td>DIVIDENDO</td>, <td>24/08/2020							  </td>, <td>1</td>]
# [<td>13/02/2020</td>, <td>1,8984</td>, <td>DIVIDENDO</td>, <td>27/02/2020							  </td>, <td>1</td>]
# [<td>09/01/2020</td>, <td>1,3523</td>, <td>REST CAP DIN</td>, <td>30/04/2020							  </td>, <td>1</td>]
# [<td>09/08/2019</td>, <td>0,8907</td>, <td>DIVIDENDO</td>, <td>21/08/2019							  </td>, <td>1</td>]
# [<td>14/02/2019</td>, <td>0,6772</td>, <td>DIVIDENDO</td>, <td>26/02/2019							  </td>, <td>1</td>]
# [<td>11/12/2018</td>, <td>1,3523</td>, <td>DIVIDENDO</td>, <td>02/01/2019							  </td>, <td>1</td>]
# [<td>09/08/2018</td>, <td>0,7809</td>, <td>DIVIDENDO</td>, <td>21/08/2018							  </td>, <td>1</td>]
# [<td>22/02/2018</td>, <td>0,9467</td>, <td>DIVIDENDO</td>, <td>06/03/2018							  </td>, <td>1</td>]
# [<td>10/08/2017</td>, <td>0,7810</td>, <td>DIVIDENDO</td>, <td>-							  </td>, <td>1</td>]
# [<td>16/02/2017</td>, <td>0,8358</td>, <td>DIVIDENDO</td>, <td>-							  </td>, <td>1</td>]
# [<td>11/08/2016</td>, <td>0,8191</td>, <td>DIVIDENDO</td>, <td>-							  </td>, <td>1</td>]
# [<td>23/02/2016</td>, <td>0,8334</td>, <td>DIVIDENDO</td>, <td>-							  </td>, <td>1</td>]
# [<td>12/08/2015</td>, <td>0,8791</td>, <td>DIVIDENDO</td>, <td>-							  </td>, <td>1</td>]
# [<td>12/02/2015</td>, <td>0,7956</td>, <td>Dividendo</td>, <td>-							  </td>, <td>1</td>]
# [<td>18/08/2014</td>, <td>0,5977</td>, <td>DIVIDENDO</td>, <td>-							  </td>, <td>1</td>]
# [<td>14/02/2014</td>, <td>0,5806</td>, <td>DIVIDENDO</td>, <td>-							  </td>, <td>1</td>]
# [<td>19/08/2013</td>, <td>0,4089</td>, <td>DIVIDENDO</td>, <td>-							  </td>, <td>1</td>]
